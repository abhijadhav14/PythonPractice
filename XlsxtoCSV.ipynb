# %% [markdown]
# <a href="https://colab.research.google.com/github/abhijadhav14/PythonPractice/blob/main/XlsxtoCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_excel('/content/drive/MyDrive/Dataset/extended_language_detection_data_set_3000.xlsx'))

# %%
df
# Out:
#         ID               Text Sample  Length  Word Count  Average Word Length  \
# 0        1  Bonjour, comment ça va ?      25           4                 4.75
# 1        2        Hola, ¿cómo estás?      19           3                 3.67
# 2        3                   你好，你好吗？       9           3                 1.67
# 3        4         Привет, как дела?      21           3                 3.67
# 4        5   Hallo, wie geht es dir?      25           5                 3.20
# ...    ...                       ...     ...         ...                  ...
# 3015  3016          안녕하세요, 어떻게 지내세요?      16           3                 4.67
# 3016  3017   Hallo, wie geht es dir?      23           5                 3.80
# 3017  3018  Bonjour, comment ça va ?      24           5                 4.00
# 3018  3019  สวัสดีคุณเป็นอย่างไรบ้าง      24           1                24.00
# 3019  3020  Bonjour, comment ça va ?      24           5                 4.00
#
# ...

# %%
df.to_csv('/content/drive/MyDrive/Dataset/extended_language_detection_data_set_3000.csv', index=False)
